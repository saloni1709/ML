# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../3/train.csv')

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
df.tail(1)
# Out:
#      PassengerId  Survived  Pclass                 Name   Sex   Age  SibSp  \
# 890          891         0       3  Dooley, Mr. Patrick  male  32.0      0
#
#      Parch  Ticket  Fare Cabin Embarked
# 890      0  370376  7.75   NaN        Q

# %%
df.sample()
# Out:
#     PassengerId  Survived  Pclass                 Name   Sex  Age  SibSp  \
# 29           30         0       3  Todoroff, Mr. Lalio  male  NaN      0
#
#     Parch  Ticket    Fare Cabin Embarked
# 29      0  349216  7.8958   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.notnull().sum().sum()
# Out:
# np.int64(2196)

# %%
df.index
# Out:
# Index([  1,   3,   6,  10,  11,  21,  23,  27,  52,  54,
#        ...
#        835, 853, 857, 862, 867, 871, 872, 879, 887, 889],
#       dtype='int64', length=183)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.shape
# Out:
# (183, 12)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.value_counts()
# Out:
# PassengerId  Survived  Pclass  Name                                                 Sex     Age   SibSp  Parch  Ticket    Fare     Cabin        Embarked
# 2            1         1       Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0  1      0      PC 17599  71.2833  C85          C           1
# 4            1         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)         female  35.0  1      0      113803    53.1000  C123         S           1
# 7            0         1       McCarthy, Mr. Timothy J                              male    54.0  0      0      17463     51.8625  E46          S           1
# 11           1         3       Sandstrom, Miss. Marguerite Rut                      female  4.0   1      1      PP 9549   16.7000  G6           S           1
# 12           1         1       Bonnell, Miss. Elizabeth                             female  58.0  0      0      113783    26.5500  C103         S           1
# ...

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 1    123
# 0     60
# Name: count, dtype: int64

# %%
sns.histplot(df['Survived'])
# Out:
# <Axes: xlabel='Survived', ylabel='Count'>

# %%
sns.distplot(df['Age'], color='red')
# Out:
# C:\Users\harsh\AppData\Local\Temp\ipykernel_3504\2853512246.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'], color='red')
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.scatterplot(x='Age', y='Fare', data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %%
plt.scatter(df['Age'], df['Fare'], color='green')

# %%
plt.boxplot(df['Fare'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1cac517d570>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1cac517da50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1cac517d270>],
#  'medians': [<matplotlib.lines.Line2D at 0x1cac52c3fd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1cac52c42b0>],
#  'means': []}

# %%
sns.boxplot(x='Pclass', y='Fare', data = df)
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %%
sns.countplot(x='Pclass', data=df, color='orange')
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.barplot(x='Pclass', y='Fare', data=df, color='cyan')
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %%
sns.barplot(x='Age', data = df)
# Out:
# <Axes: xlabel='Age'>

# %%
sns.pairplot(df[['Age', 'Fare']])

# %%
sns.pairplot(df)

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.sample()
# Out:
#      PassengerId  Survived  Pclass  \
# 299          300         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 299  Baxter, Mrs. James (Helene DeLaudeniere Chaput)  female  50.0      0
#
#      Parch    Ticket      Fare    Cabin Embarked
# 299      1  PC 17558  247.5208  B58 B60        C

# %%
df.head(1)
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch    Ticket     Fare Cabin Embarked
# 1      0  PC 17599  71.2833   C85        C

# %%
X = df.drop(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked', 'Survived'], axis = 1)
y = df.iloc[:, -1]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y, 
    test_size = 0.25,
    random_state = 42
)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# c:\Users\harsh\Desktop\Saloni\ml\.venv\lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = lr.predict(X_test)

# %%
y_pred
# Out:
# array(['C', 'S', 'C', 'S', 'S', 'S', 'S', 'C', 'S', 'S', 'S', 'S', 'S',
#        'S', 'S', 'S', 'S', 'S', 'S', 'S', 'C', 'C', 'S', 'S', 'S', 'S',
#        'C', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'C', 'S', 'S', 'S', 'S',
#        'S', 'S', 'S', 'S', 'S', 'S', 'S'], dtype=object)

# %%
lr.coef_
# Out:
# array([[ 0.00118079, -0.31909225,  0.01295621, -0.4083644 , -0.11507603,
#          0.00742266],
#        [-0.00240738, -0.20545466, -0.02365556,  0.22092531, -0.19291762,
#         -0.0022466 ],
#        [ 0.00122659,  0.52454691,  0.01069936,  0.18743909,  0.30799365,
#         -0.00517606]])

# %%
lr.intercept_
# Out:
# array([-0.13633511, -0.0956368 ,  0.2319719 ])

# %%
lr.decision_function(X_test)
# Out:
# array([[ 1.71822251, -1.90430032,  0.18607781],
#        [-0.86610388, -2.00016811,  2.86627199],
#        [ 1.59461916, -3.11997465,  1.52535549],
#        [ 1.2175053 , -2.81405838,  1.59655308],
#        [ 0.98598712, -3.04891525,  2.06292813],
#        [ 0.83622615, -2.29200582,  1.45577967],
#        [ 0.60870682, -1.3837882 ,  0.77508138],
#        [ 1.47323172, -2.3868301 ,  0.91359838],
#        [ 0.73892312, -2.51978119,  1.78085807],
#        [ 1.06568413, -2.85750489,  1.79182076],
#        [ 1.09271067, -2.91463741,  1.82192674],
#        [ 1.28011723, -3.30579075,  2.02567353],
#        [ 0.79257465, -2.26385377,  1.47127911],
#        [ 1.13081981, -3.39504028,  2.26422047],
#        [ 0.5966174 , -2.31525442,  1.71863702],
#        [ 0.31349387, -1.41635052,  1.10285665],
#        [ 0.40321662, -1.43719403,  1.03397741],
#        [ 0.54088907, -1.8225074 ,  1.28161833],
#        [-0.11152155, -2.52223547,  2.63375702],
#        [ 0.5284746 , -1.46843712,  0.93996253],
# ...

# %%
sns.kdeplot(df['Age'], color='red')
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.clustermap(df[['Age', 'Fare']])

# %%
df.min()
# Out:
# PassengerId                                2
# Survived                                   0
# Pclass                                     1
# Name           Allen, Miss. Elisabeth Walton
# Sex                                   female
# Age                                     0.92
# SibSp                                      0
# Parch                                      0
# Ticket                                110152
# Fare                                     0.0
# Cabin                                    A10
# Embarked                                   C
# dtype: object

# %%
df.max()
# Out:
# PassengerId                         890
# Survived                              1
# Pclass                                3
# Name           Young, Miss. Marie Grice
# Sex                                male
# Age                                80.0
# SibSp                                 3
# Parch                                 4
# Ticket                        WE/P 5735
# Fare                           512.3292
# Cabin                                 T
# Embarked                              S
# dtype: object

# %%
df.mean(numeric_only=True)
# Out:
# PassengerId    455.366120
# Survived         0.672131
# Pclass           1.191257
# Age             35.674426
# SibSp            0.464481
# Parch            0.475410
# Fare            78.682469
# dtype: float64

# %%
df.select_dtypes(include='number')
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 1              2         1       1  38.0      1      0  71.2833
# 3              4         1       1  35.0      1      0  53.1000
# 6              7         0       1  54.0      0      0  51.8625
# 10            11         1       3   4.0      1      1  16.7000
# 11            12         1       1  58.0      0      0  26.5500
# ..           ...       ...     ...   ...    ...    ...      ...
# 871          872         1       1  47.0      1      1  52.5542
# 872          873         0       1  33.0      0      0   5.0000
# 879          880         1       1  56.0      0      1  83.1583
# 887          888         1       1  19.0      0      0  30.0000
# 889          890         1       1  26.0      0      0  30.0000
#
# [183 rows x 7 columns]

# %%
df.select_dtypes(include='number').mean()
# Out:
# PassengerId    455.366120
# Survived         0.672131
# Pclass           1.191257
# Age             35.674426
# SibSp            0.464481
# Parch            0.475410
# Fare            78.682469
# dtype: float64

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
df['Sex'] = df['Sex'].map({
    'male' : 1,
    'female': 0
})

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
#
#       Ticket     Fare Cabin Embarked
# 0  A/5 21171   7.2500   NaN        S
# 1   PC 17599  71.2833   C85        C

# %%
X_train.shape
# Out:
# (137, 6)

# %%
y_train.shape
# Out:
# (137,)

# %%
X_test.shape
# Out:
# (46, 6)

# %%
y_test.shape
# Out:
# (46,)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
sc.fit(X_train, y_train)
# Out:
# StandardScaler()
